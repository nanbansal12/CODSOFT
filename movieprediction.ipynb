# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("C:/Users/HP/IMDb Movies India.csv", encoding='latin1')
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df_cleaned = df.dropna()

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')

# %%
print(df['Year'].mode())
print(df['Duration'].mode())
# Out:
# Series([], Name: Year, dtype: float64)
# Series([], Name: Duration, dtype: float64)

# %%
print(df['Year'].unique()[:20])       # Check first 20 unique values
print(df['Duration'].unique()[:20])   # Same for Duration
# Out:
# [nan]
# [nan]

# %%
df = pd.read_csv("C:/Users/HP/IMDb Movies India.csv", encoding='latin1')  # or use your working version
print(df[['Year', 'Duration']].head(10))
# Out:
#      Year Duration
# 0     NaN      NaN
# 1  (2019)  109 min
# 2  (2021)   90 min
# 3  (2019)  110 min
# 4  (2010)  105 min
# 5  (1997)  147 min
# 6  (2005)  142 min
# 7  (2008)   59 min
# 8  (2012)   82 min
# 9  (2014)  116 min

# %%
# Clean 'Year': extract the 4-digit number from '(2019)'
df['Year'] = df['Year'].astype(str).str.extract(r'(\d{4})')
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Clean 'Duration': extract the number from '109 min'
df['Duration'] = df['Duration'].astype(str).str.extract(r'(\d+)')
df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')

# %%
print(df['Year'].unique()[:10])
print(df['Duration'].unique()[:10])
# Out:
# [  nan 2019. 2021. 2010. 1997. 2005. 2008. 2012. 2014. 2004.]
# [ nan 109.  90. 110. 105. 147. 142.  59.  82. 116.]

# %%
df['Year'] = df['Year'].fillna(df['Year'].mode().iloc[0])
df['Duration'] = df['Duration'].fillna(df['Duration'].mode().iloc[0])

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['Genre', 'Director', 'Actor 1', 'Actor 2', 'Actor 3']
le = LabelEncoder()

for col in categorical_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df=df.dropna(subset=['Rating'])

# %%
X = df.drop(['Rating', 'Name'], axis=1)  # Drop columns you don't want as input
y = df['Rating']

# %%
print(y_train.head())
print(y_train.shape)
print(type(y_train))
# Out:
# 8157     8.8
# 8455     6.0
# 14490    3.8
# 2697     5.8
# 15470    8.2
# Name: Rating, dtype: float64
# (6335,)
# <class 'pandas.core.series.Series'>

# %%
print(df['Rating'].dtype)
# Out:
# float64

# %%
# One-hot encode categorical columns (example: 'Genre')
X = pd.get_dummies(X, columns=['Genre'])  # Replace 'Genre' with your column name(s)

# Check the processed features
print(X.head())
# Out:
#      Year  Duration  Votes  Director  Actor 1  Actor 2  Actor 3  Genre_0  \
# 1  2019.0     109.0   1848       611     2536     4213     4297    False
# 3  2019.0     110.0   1168      2579     2132      563     3359    False
# 5  1997.0     147.0   1897      3114     4603      258     3145    False
# 6  2005.0     142.0     34      4438      777     1512     4182    False
# 8  2012.0      82.0   1137      2280     4062     1649      948    False
#
#    Genre_1  Genre_2  ...  Genre_474  Genre_475  Genre_476  Genre_477  \
# 1    False    False  ...      False      False      False      False
# 3    False    False  ...      False      False      False      False
# 5    False    False  ...      False      False      False      False
# 6    False    False  ...      False      False      False      False
# 8    False    False  ...      False      False      False      False
#
#    Genre_479  Genre_480  Genre_481  Genre_482  Genre_484  Genre_485
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2,  # 20% for testing
    random_state=42  # For reproducibility
)

# Verify shapes
print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
# Out:
# Training data shape: (6335, 440)
# Testing data shape: (1584, 440)

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the model
model = RandomForestRegressor(
    n_estimators=100,  # Number of trees
    random_state=42
)

# Train the model
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predict on test data
y_pred = model.predict(X_test)

# Calculate metrics
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error (MAE): 0.9264387626262625
# Mean Squared Error (MSE): 1.4308394008838383
# R² Score: 0.2303777851419776

# %%
# Example new movie data (adjust columns)
new_movie = {
    'Year': [2023],
    'Runtime': [120],
    'Genre': ['Action']  # Must match training categories
}

# Convert to DataFrame and encode genres
new_movie_df = pd.DataFrame(new_movie)
new_movie_df = pd.get_dummies(new_movie_df, columns=['Genre'])  # Use square brackets, not curly braces

# Align columns with training data (EFFICIENT VERSION)
# Step 1: Create a DataFrame of zeros with the same columns as X_train
new_movie_aligned = pd.DataFrame(0, index=[0], columns=X_train.columns)

# Step 2: Update with values from new_movie_df where columns overlap
for col in new_movie_df.columns:
    if col in new_movie_aligned.columns:
        new_movie_aligned[col] = new_movie_df[col]

# Now predict
predicted_rating = model.predict(new_movie_aligned)
print("Predicted Rating:", predicted_rating[0])
# Out:
# Predicted Rating: 6.2090000000000005

# %%
import joblib
joblib.dump(model, 'movie_rating_model.pkl')
# Out:
# ['movie_rating_model.pkl']
